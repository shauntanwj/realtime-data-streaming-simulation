# %% [markdown]
# ### Task 1: Querying MongoDB using PyMongo

# %% [markdown]
# 1. Write a python program that will read the data from hotspot_historic.csv andclimate_historic.csv and load them to the new database(e.g.assignment_db).</br>- Please use a csv library to read the files.</br>- Please DO NOT use the mongo aggregation query to do this task.

# %%
# import the necessary library
import pymongo
from pymongo import MongoClient
import pandas as pd
from datetime import datetime
from pprint import pprint
print("Pandas Version: " + pd.__version__)
# Out:
# Pandas Version: 1.4.2

# %%
# create a MongoClient
client = MongoClient()
db = client.assignment_db

# %% [markdown]
# Create the 2 collections, climate_historic and hotspot_historic

# %%
# Drop the collections if they exist
db.climate_historic.drop()
db.hotspot_historic.drop()

# Create 2 collections for climate_historic and hotspot_historic
climate_historic = db.climate_historic
hotspot_historic = db.hotspot_historic

# %% [markdown]
# Reading the *climate_historic.csv* file using pandas library, format the data and insert it into the climate_historic collection

# %%
# read the climate_historic.csv file using pandas read_csv function
climate_historic_reader = pd.read_csv('climate_historic.csv')

# insert each climate historic data into the climate_historic_collection
for i in range(len(climate_historic_reader)):
    precipitation_data = climate_historic_reader["precipitation "][i].replace(" ", "")
    
    # prepare the climate data in the correct format and datatype
    climate_data = {
            "station": int(climate_historic_reader["station"][i]), 
            "date": datetime.strptime(climate_historic_reader["date"][i], "%d/%m/%y"), 
            "air_temperature_celcius": int(climate_historic_reader["air_temperature_celcius"][i]),
            "relative_humidity": float(climate_historic_reader["relative_humidity"][i]),
            "windspeed_knots": float(climate_historic_reader["windspeed_knots"][i]),
            "max_wind_speed": float(climate_historic_reader["max_wind_speed"][i]),
            "precipitation": {"amount": float(precipitation_data[-len(precipitation_data):-1]), "flag": precipitation_data[-1]},
            "GHI_w/m2": int(climate_historic_reader["GHI_w/m2"][i])
            
           }
    climate_historic.insert_one(climate_data)

# %% [markdown]
# Reading the *hotspot_historic.csv* file, format the data and insert it into the hotspot_historic collection

# %%
# read the hotspot_historic.csv file using pandas read_csv function
hotspot_historic_reader = pd.read_csv("hotspot_historic.csv")

# insert each hotspot historic data into the hotspot_historic_collection
for i in range(len(hotspot_historic_reader)):
    
    # prepare the hotspot data in the correct format and datatype
    hotspot_data = {
            "latitude": float(hotspot_historic_reader["latitude"][i]),
            "longitude": float(hotspot_historic_reader["longitude"][i]), 
            "datetime": datetime.strptime(hotspot_historic_reader["datetime"][i], "%Y-%m-%dT%H:%M:%S"),
            "confidence": int(hotspot_historic_reader["confidence"][i]),
            "date": datetime.strptime(hotspot_historic_reader["date"][i], '%d/%m/%Y'),
            "surface_temperature_celcius": int(hotspot_historic_reader["surface_temperature_celcius"][i])
           }
    hotspot_historic.insert_one(hotspot_data)

# %% [markdown]
# Shows that the database *assignment.db* has been created

# %%
for x in client.list_databases():
    print(x)
# Out:
# {'name': 'admin', 'sizeOnDisk': 40960.0, 'empty': False}
# {'name': 'config', 'sizeOnDisk': 110592.0, 'empty': False}
# {'name': 'fit3182_assignment_db', 'sizeOnDisk': 163840.0, 'empty': False}
# {'name': 'fit3182_db', 'sizeOnDisk': 73728.0, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 81920.0, 'empty': False}

# %% [markdown]
# Shows the example of the climate data in the climate_historic collection

# %%
# sample of the document in climate_historic collection
climate_doc = climate_historic.find({}).limit(1)
for x in climate_doc: 
    pprint(x)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6eaa'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2020, 12, 31, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}

# %% [markdown]
# Shows the example of the hotspot data in the hotspot_historic collection

# %%
# sample of the document in hotspot_historic collection
hotspot_doc = hotspot_historic.find({}).limit(1)
for x in hotspot_doc: 
    pprint(x)
# Out:
# {'_id': ObjectId('628a65b2cc5bb730f6ed7018'),
#  'confidence': 78,
#  'date': datetime.datetime(2021, 12, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 27, 4, 16, 51),
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}

# %%
climate_historic.count_documents({})
# Out:
# 366

# %%
hotspot_historic.count_documents({})
# Out:
# 2668

# %% [markdown]
# 2. Write queries to answer the following tasks on assignment_db and corresponding collection(s). You need to write the queries as a python program using the pymongo library in Jupyter Notebook.</br>

# %% [markdown]
# a. Find climate data on 12th December 2021.

# %%
climate_historic.find_one({"date": {'$eq': datetime(2021, 12, 12)}})
# Out:
# {'_id': ObjectId('628a65b1cc5bb730f6ed7003'),
#  'station': 948702,
#  'date': datetime.datetime(2021, 12, 12, 0, 0),
#  'air_temperature_celcius': 19,
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2,
#  'max_wind_speed': 12.0,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'GHI_w/m2': 156}

# %% [markdown]
# b. Find the latitude, longitude, surface temperature (°C), and confidence when
# the surface temperature (°C) was between 65 °C and 100 °C.

# %%
query_b_results = hotspot_historic.find({"surface_temperature_celcius":{"$gte":65, "$lte":100}},
                                           {"_id":0,"latitude":1, "longitude":1, 
                                            "surface_temperature_celcius":1, "confidence":1})
for result in query_b_results:
    pprint(result)
# Out:
# {'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.462,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.081,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.401,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
# {'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
# {'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
# {'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.663,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
# {'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.803,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.272,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'confidence': 93,
#  'latitude': -36.388,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
# {'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.538,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
# {'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.978,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'confidence': 93,
#  'latitude': -36.663,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
# {'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
# {'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
# {'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
# {'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
# {'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
# {'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
# {'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
# {'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
# {'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
# {'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
# {'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
# {'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
# {'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
# {'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -36.7287,
#  'longitude': 142.6017,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
# {'confidence': 98,
#  'latitude': -35.2381,
#  'longitude': 142.994,
#  'surface_temperature_celcius': 83}
# {'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
# {'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.224,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
# {'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
# {'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
# {'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'confidence': 83,
#  'latitude': -37.803,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.081,
#  'surface_temperature_celcius': 81}
# {'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
# {'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.913,
#  'surface_temperature_celcius': 83}
# {'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
# {'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
# {'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.728,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
# {'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.897,
#  'surface_temperature_celcius': 80}
# {'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
# {'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
# {'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.027,
#  'surface_temperature_celcius': 99}
# {'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}

# %% [markdown]
# c. Find date, surface temperature (°C), air temperature (°C), relative humidity and
# max wind speed on 15th and 16th of December 2021.

# %% [markdown]
# 1. First join the hotspot_historic collection with the climate_historic collection based on the common attribute "date" using "\\$lookup".
# 2. Second use "\\$project" to only show the required data for the output.
# 3. Last use "\\$match" to specifies the condition for the query.

# %%
query_c_results = hotspot_historic.aggregate([
    {
        "$lookup": {
            "from": "climate_historic",
            "localField": "date",
            "foreignField": "date",
            "as": "climate_data"
        }
    },
    
    {
        "$project": {
            "_id": 0,
            "date": 1,
            "surface_temperature_celcius": 1,
            "climate_data.air_temperature_celcius": 1,
            "climate_data.relative_humidity": 1,
            "climate_data.max_wind_speed": 1
        }
    },
    
    {
        "$match": {
            "$or":[{"date": {'$eq': datetime(2021, 12, 15, 0, 0)}}, 
                    {"date": {'$eq': datetime(2021, 12, 16, 0, 0)}}]
        }
    },
])
for result in query_c_results:
    pprint(result)
# Out:
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 43}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 33}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 66}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 13.0,
#                    'relative_humidity': 53.7}],
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 14.0,
#                    'relative_humidity': 52.0}],
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'surface_temperature_celcius': 42}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 14.0,
#                    'relative_humidity': 52.0}],
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'surface_temperature_celcius': 36}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 14.0,
#                    'relative_humidity': 52.0}],
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'surface_temperature_celcius': 38}
# {'climate_data': [{'air_temperature_celcius': 18,
#                    'max_wind_speed': 14.0,
#                    'relative_humidity': 52.0}],
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'surface_temperature_celcius': 40}

# %% [markdown]
# d. Find datetime, air temperature (°C), surface temperature (°C) and confidence
# when the confidence is between 80 and 100.

# %% [markdown]
# 1. First join the hotspot_historic collection with the climate_historic collection based on the common attribute "date" using "\\$lookup".
# 2. Second use "\\$project" to only show the required data for the output.
# 3. Last use "\\$match" to specifies the condition for the query.

# %%
query_d_results = hotspot_historic.aggregate([
    {
        "$lookup": {
            "from": "climate_historic",
            "localField": "date",
            "foreignField": "date",
            "as": "climate_data"
        }
    },
    {
        "$project": {
            "_id": 0,
            "datetime": 1,
            "climate_data.air_temperature_celcius": 1,
            "surface_temperature_celcius": 1,
            "confidence": 1
        }
    },
    {
        "$match": {
            "$and": [{"confidence":{"$gte":80}}, {"confidence":{"$lte":100}}]}
    }
])
for document in query_d_results:
    pprint(document)
# Out:
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 14),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 12, 25, 4, 29, 8),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#  'surface_temperature_celcius': 43}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 35, 13),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 58),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#  'surface_temperature_celcius': 66}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 12),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#  'surface_temperature_celcius': 42}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 12, 14, 4, 47, 25),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 12, 13, 4, 4, 19),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 34),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 12, 9, 0, 14, 33),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 44),
#  'surface_temperature_celcius': 71}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'surface_temperature_celcius': 49}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 38}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 42}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 14),
#  'surface_temperature_celcius': 71}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 35),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 83}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'surface_temperature_celcius': 86}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 87}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'surface_temperature_celcius': 84}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 11, 23, 4, 28, 59),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 11, 22, 3, 46),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 11, 21, 0, 27, 21),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 28}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 14, 4, 35, 4),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 15),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 14),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 37}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 11, 13, 30, 8),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 11, 11, 4, 4, 25),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 93}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 48),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 44),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 34),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 11, 5, 4, 41, 19),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 10, 28, 3, 52, 17),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 22}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 26, 13, 30, 31),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 55),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 46}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 20, 4, 41, 19),
#  'surface_temperature_celcius': 50}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 26}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 18, 0, 39, 2),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 22}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 10, 17, 13, 36, 12),
#  'surface_temperature_celcius': 43}
# {'climate_data': [{'air_temperature_celcius': 22}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 45),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 22}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 32),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 87}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 10, 15, 4, 23, 1),
#  'surface_temperature_celcius': 85}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 10, 10, 4, 4, 19),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 10, 7, 12, 59, 33),
#  'surface_temperature_celcius': 42}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41, 2),
#  'surface_temperature_celcius': 46}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 46}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 10, 3, 13, 23, 43),
#  'surface_temperature_celcius': 42}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 49}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 15),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 90}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 14),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 10),
#  'surface_temperature_celcius': 50}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 9),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 10, 1, 15, 13, 56),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 9, 29, 4, 22, 31),
#  'surface_temperature_celcius': 49}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 36),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 41}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 47),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 43}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 15, 7, 45),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 10),
#  'surface_temperature_celcius': 47}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 38}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 7),
#  'surface_temperature_celcius': 50}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 19),
#  'surface_temperature_celcius': 88}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 4),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 23, 23, 50, 44),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 50}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 84}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 23, 12, 47, 12),
#  'surface_temperature_celcius': 79}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 13),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 11),
#  'surface_temperature_celcius': 50}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 29, 3),
#  'surface_temperature_celcius': 112}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 9, 20, 4, 28, 45),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 9, 10, 4, 0),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 53),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 50, 30),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 9, 10, 3, 50, 10),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 8),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 5, 10),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 8, 13, 5, 2, 30),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 5}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 8, 2, 3, 45, 40),
#  'surface_temperature_celcius': 87}
# {'climate_data': [{'air_temperature_celcius': 7}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 8, 1, 0, 20, 30),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 7}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#  'surface_temperature_celcius': 51}
# {'climate_data': [{'air_temperature_celcius': 7}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 7, 31, 13, 21),
#  'surface_temperature_celcius': 43}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 7, 6, 4, 8),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 7, 6, 4, 2),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 6}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 18),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 6}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 5}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 30, 0, 27, 19),
#  'surface_temperature_celcius': 48}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 88}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 6, 20, 4, 2),
#  'surface_temperature_celcius': 89}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 6, 14, 4, 43),
#  'surface_temperature_celcius': 85}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 6, 9, 4, 23, 20),
#  'surface_temperature_celcius': 52}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 9, 4, 23, 16),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 35, 50),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 33, 50),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 8}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 8, 20),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 8, 10),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 12}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 11}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 6, 1, 5, 9, 20),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 13}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 26, 4, 8, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 23, 0, 58),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 23, 0, 54, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 43, 30),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 34, 10),
#  'surface_temperature_celcius': 101}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 82}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 93}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 15),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'surface_temperature_celcius': 90}
# {'climate_data': [{'air_temperature_celcius': 17}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 34, 30),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 101}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 31, 20),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 31, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 30),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 50),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 94}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28),
#  'surface_temperature_celcius': 87}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 27, 50),
#  'surface_temperature_celcius': 66}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 111}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 66}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 110}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 74}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 15, 0, 12, 10),
#  'surface_temperature_celcius': 90}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 45, 40),
#  'surface_temperature_celcius': 102}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 43, 30),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 41, 50),
#  'surface_temperature_celcius': 98}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#  'surface_temperature_celcius': 120}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 10),
#  'surface_temperature_celcius': 90}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39, 30),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 50),
#  'surface_temperature_celcius': 93}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 113}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 95}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 12, 3, 57, 40),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 5, 12, 3, 56, 10),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 12, 3, 56, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 57, 20),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 57, 20),
#  'surface_temperature_celcius': 79}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 54),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 51),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 86}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 69}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 81}
# {'climate_data': [{'air_temperature_celcius': 9}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 11, 4, 50, 40),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 16, 30),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 16, 10),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 14, 20),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 14, 10),
#  'surface_temperature_celcius': 103}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 12, 50),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 12, 50),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 11, 30),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 11, 10),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 11, 10),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 83}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 82}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 50),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 30),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 84}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 71}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 89}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 113}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 78}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 10}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 5, 10, 4, 8, 10),
#  'surface_temperature_celcius': 74}
# ...
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 86}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 72}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 15}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 4, 3, 1, 7, 20),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 31, 5, 7, 10),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 31, 5, 1, 20),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 31, 4, 58, 30),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 31, 4, 58),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#  'surface_temperature_celcius': 61}
# {'climate_data': [{'air_temperature_celcius': 14}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 31, 0, 36, 30),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 38),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 33, 40),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 33, 30),
#  'surface_temperature_celcius': 71}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 33, 30),
#  'surface_temperature_celcius': 76}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 32, 20),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 50),
#  'surface_temperature_celcius': 56}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 20),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 74}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 82}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 30, 10),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 28, 30),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 40),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 20),
#  'surface_temperature_celcius': 107}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27, 10),
#  'surface_temperature_celcius': 108}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 99,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 27),
#  'surface_temperature_celcius': 86}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 90}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 63}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 81}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 83,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 57}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 43, 20),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 40, 50),
#  'surface_temperature_celcius': 53}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 50),
#  'surface_temperature_celcius': 54}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 91,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 89}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 82,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 59, 50),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 58, 10),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 111}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 57, 10),
#  'surface_temperature_celcius': 77}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#  'surface_temperature_celcius': 99}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 50),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'surface_temperature_celcius': 79}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#  'surface_temperature_celcius': 66}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 98,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33),
#  'surface_temperature_celcius': 83}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 91}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'surface_temperature_celcius': 58}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 113}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 92,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 70}
# {'climate_data': [{'air_temperature_celcius': 24}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 40),
#  'surface_temperature_celcius': 106}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#  'surface_temperature_celcius': 121}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 40),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 48, 20),
#  'surface_temperature_celcius': 74}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 45, 10),
#  'surface_temperature_celcius': 59}
# {'climate_data': [{'air_temperature_celcius': 18}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 17, 4, 45),
#  'surface_temperature_celcius': 60}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 24, 40),
#  'surface_temperature_celcius': 67}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 93,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 22, 20),
#  'surface_temperature_celcius': 72}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 90,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 20, 50),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 95,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 16, 30),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 89,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 16, 20),
#  'surface_temperature_celcius': 65}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 40),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 96,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 79}
# {'climate_data': [{'air_temperature_celcius': 25}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 14, 4, 14, 30),
#  'surface_temperature_celcius': 75}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 33, 50),
#  'surface_temperature_celcius': 105}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 84,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 29, 50),
#  'surface_temperature_celcius': 71}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 28, 20),
#  'surface_temperature_celcius': 99}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 80,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 28),
#  'surface_temperature_celcius': 68}
# {'climate_data': [{'air_temperature_celcius': 21}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 12, 4, 27, 20),
#  'surface_temperature_celcius': 98}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 48, 40),
#  'surface_temperature_celcius': 105}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 100,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 46, 20),
#  'surface_temperature_celcius': 109}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 94,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 73}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 97,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 45, 30),
#  'surface_temperature_celcius': 80}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 81,
#  'datetime': datetime.datetime(2021, 3, 10, 4, 43, 50),
#  'surface_temperature_celcius': 55}
# {'climate_data': [{'air_temperature_celcius': 23}],
#  'confidence': 86,
#  'datetime': datetime.datetime(2021, 3, 9, 13, 23, 40),
#  'surface_temperature_celcius': 41}
# {'climate_data': [{'air_temperature_celcius': 19}],
#  'confidence': 88,
#  'datetime': datetime.datetime(2021, 3, 7, 4, 16, 10),
#  'surface_temperature_celcius': 64}
# {'climate_data': [{'air_temperature_celcius': 20}],
#  'confidence': 87,
#  'datetime': datetime.datetime(2021, 3, 6, 5, 6, 30),
#  'surface_temperature_celcius': 62}
# {'climate_data': [{'air_temperature_celcius': 20}],
#  'confidence': 85,
#  'datetime': datetime.datetime(2021, 3, 6, 5, 6, 20),
#  'surface_temperature_celcius': 59}

# %% [markdown]
# e. Find the top 10 records with the highest surface temperature (°C).

# %%
# sort the hotspot_historic data descendingly based on the surface_temperature_celcius and get the top 10
query_e_results = hotspot_historic.find().sort("surface_temperature_celcius", -1).limit(10)
for document in query_e_results:
    pprint(document)
# Out:
# {'_id': ObjectId('628a65b3cc5bb730f6ed74bb'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 18, 4, 52),
#  'latitude': -38.1665,
#  'longitude': 143.062,
#  'surface_temperature_celcius': 124}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7965'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 50),
#  'latitude': -36.343,
#  'longitude': 142.1986,
#  'surface_temperature_celcius': 123}
# {'_id': ObjectId('628a65b3cc5bb730f6ed742d'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 1, 4, 14, 20),
#  'latitude': -36.9318,
#  'longitude': 143.0907,
#  'surface_temperature_celcius': 122}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a54'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 3, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 18, 3, 50, 50),
#  'latitude': -37.017,
#  'longitude': 148.1297,
#  'surface_temperature_celcius': 121}
# {'_id': ObjectId('628a65b2cc5bb730f6ed723f'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#  'latitude': -34.9938,
#  'longitude': 141.876,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a65b3cc5bb730f6ed792c'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 40),
#  'latitude': -36.1057,
#  'longitude': 141.7608,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a65b3cc5bb730f6ed796c'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#  'latitude': -36.3521,
#  'longitude': 142.2008,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a65b3cc5bb730f6ed76d7'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 13, 4, 28, 10),
#  'latitude': -37.0745,
#  'longitude': 141.0692,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7554'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 4, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 18, 4, 44, 50),
#  'latitude': -37.8326,
#  'longitude': 143.4999,
#  'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7383'),
#  'confidence': 100,
#  'date': datetime.datetime(2021, 5, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 4, 4, 44, 50),
#  'latitude': -36.4057,
#  'longitude': 140.9806,
#  'surface_temperature_celcius': 119}

# %% [markdown]
# f. Find the number of fires each day. You are required to only display the total
# number of fires and the date in the output.

# %%
query_f_results = hotspot_historic.aggregate([{"$group":{"_id":"$date", "count":{"$sum":1}}}])
for document in query_f_results:
    pprint(document)
# Out:
# {'_id': datetime.datetime(2021, 12, 27, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 7, 14, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 7, 5, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 1, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2021, 9, 21, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 8, 5, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 23, 0, 0), 'count': 19}
# {'_id': datetime.datetime(2021, 3, 7, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 6, 18, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 6, 13, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 10, 28, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 11, 8, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 10, 21, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 12, 24, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 10, 3, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2021, 5, 11, 0, 0), 'count': 19}
# {'_id': datetime.datetime(2021, 5, 3, 0, 0), 'count': 64}
# {'_id': datetime.datetime(2021, 4, 11, 0, 0), 'count': 24}
# {'_id': datetime.datetime(2021, 11, 12, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 5, 8, 0, 0), 'count': 24}
# {'_id': datetime.datetime(2021, 4, 26, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 3, 14, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2021, 9, 23, 0, 0), 'count': 23}
# {'_id': datetime.datetime(2021, 5, 14, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 5, 15, 0, 0), 'count': 102}
# {'_id': datetime.datetime(2021, 12, 12, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 13, 0, 0), 'count': 357}
# {'_id': datetime.datetime(2021, 7, 4, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 10, 23, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 4, 0, 0), 'count': 89}
# {'_id': datetime.datetime(2021, 4, 7, 0, 0), 'count': 39}
# {'_id': datetime.datetime(2021, 5, 4, 0, 0), 'count': 135}
# {'_id': datetime.datetime(2021, 5, 13, 0, 0), 'count': 54}
# {'_id': datetime.datetime(2021, 12, 15, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 4, 20, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2021, 6, 3, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 4, 25, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 5, 23, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 12, 25, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 8, 10, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 16, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2021, 11, 29, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2021, 3, 24, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 10, 7, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 10, 6, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 11, 9, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2021, 3, 8, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 11, 22, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 3, 19, 0, 0), 'count': 21}
# {'_id': datetime.datetime(2021, 7, 31, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 4, 17, 0, 0), 'count': 38}
# {'_id': datetime.datetime(2021, 8, 14, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 4, 6, 0, 0), 'count': 118}
# {'_id': datetime.datetime(2021, 11, 11, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 4, 29, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 5, 17, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 6, 20, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2021, 12, 9, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 10, 8, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 5, 24, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 4, 15, 0, 0), 'count': 69}
# {'_id': datetime.datetime(2021, 11, 30, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2021, 3, 10, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2021, 9, 24, 0, 0), 'count': 28}
# {'_id': datetime.datetime(2021, 10, 18, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2021, 9, 27, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2021, 6, 1, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 3, 25, 0, 0), 'count': 13}
# {'_id': datetime.datetime(2021, 8, 1, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 3, 13, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 6, 14, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 4, 12, 0, 0), 'count': 69}
# {'_id': datetime.datetime(2021, 3, 29, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 7, 2, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2021, 6, 4, 0, 0), 'count': 9}
# {'_id': datetime.datetime(2021, 10, 10, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 12, 21, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 7, 6, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 10, 26, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 5, 22, 0, 0), 'count': 33}
# {'_id': datetime.datetime(2021, 5, 10, 0, 0), 'count': 114}
# {'_id': datetime.datetime(2021, 3, 18, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 10, 1, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2021, 7, 1, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 9, 10, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 10, 16, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 12, 10, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 10, 27, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 5, 5, 0, 0), 'count': 31}
# {'_id': datetime.datetime(2021, 11, 14, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 10, 9, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 9, 22, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 6, 2, 0, 0), 'count': 11}
# {'_id': datetime.datetime(2021, 4, 2, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 3, 31, 0, 0), 'count': 22}
# {'_id': datetime.datetime(2021, 3, 15, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2021, 11, 5, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 3, 9, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 3, 28, 0, 0), 'count': 54}
# {'_id': datetime.datetime(2021, 3, 26, 0, 0), 'count': 17}
# {'_id': datetime.datetime(2021, 12, 13, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 10, 4, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 12, 14, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 3, 17, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2021, 4, 22, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 10, 20, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 6, 22, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 11, 13, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 4, 14, 0, 0), 'count': 18}
# {'_id': datetime.datetime(2021, 5, 2, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2021, 8, 13, 0, 0), 'count': 9}
# {'_id': datetime.datetime(2021, 12, 8, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 11, 23, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 10, 15, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 9, 20, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 4, 5, 0, 0), 'count': 49}
# {'_id': datetime.datetime(2021, 6, 9, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 7, 29, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 5, 9, 0, 0), 'count': 13}
# {'_id': datetime.datetime(2021, 9, 29, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 4, 19, 0, 0), 'count': 50}
# {'_id': datetime.datetime(2021, 4, 24, 0, 0), 'count': 8}
# {'_id': datetime.datetime(2021, 3, 12, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 5, 18, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2021, 4, 3, 0, 0), 'count': 72}
# {'_id': datetime.datetime(2021, 9, 26, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 6, 7, 0, 0), 'count': 14}
# {'_id': datetime.datetime(2021, 6, 11, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 5, 26, 0, 0), 'count': 4}
# {'_id': datetime.datetime(2021, 6, 30, 0, 0), 'count': 6}
# {'_id': datetime.datetime(2021, 8, 2, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 5, 1, 0, 0), 'count': 20}
# {'_id': datetime.datetime(2021, 5, 6, 0, 0), 'count': 17}
# {'_id': datetime.datetime(2021, 5, 16, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 5, 12, 0, 0), 'count': 10}
# {'_id': datetime.datetime(2021, 6, 16, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 4, 8, 0, 0), 'count': 20}
# {'_id': datetime.datetime(2021, 3, 6, 0, 0), 'count': 2}
# {'_id': datetime.datetime(2021, 5, 7, 0, 0), 'count': 3}
# {'_id': datetime.datetime(2021, 10, 17, 0, 0), 'count': 5}
# {'_id': datetime.datetime(2021, 12, 16, 0, 0), 'count': 15}
# {'_id': datetime.datetime(2021, 10, 2, 0, 0), 'count': 7}
# {'_id': datetime.datetime(2021, 11, 28, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 11, 21, 0, 0), 'count': 1}
# {'_id': datetime.datetime(2021, 4, 18, 0, 0), 'count': 325}

# %% [markdown]
# g. Find the records of fires where the confidence is below 70.

# %%
results = hotspot_historic.find({"confidence":{"$lt":70}})
for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('628a65b2cc5bb730f6ed701a'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 12, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a65b2cc5bb730f6ed701d'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 12, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 24, 13, 12, 1),
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7020'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 15, 38, 39),
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7021'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 4, 35, 15),
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7025'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 4, 34, 57),
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a65b2cc5bb730f6ed702a'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 0, 21, 11),
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b2cc5bb730f6ed702d'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 12, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 16, 0, 20, 53),
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7030'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 15, 13, 17, 17),
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7031'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 12, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 15, 1, 16, 23),
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7034'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 12, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 12, 0, 45, 38),
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7035'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 12, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 10, 0, 57, 59),
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7036'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 12, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 10, 0, 56, 57),
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b2cc5bb730f6ed703f'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 12, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 12, 8, 13, 11, 43),
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7040'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 23, 25, 57),
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7042'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7043'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 36),
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7045'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 35),
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7047'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 15, 38, 32),
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7048'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7049'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 12, 22, 15),
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7055'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 4, 34, 57),
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7056'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 21),
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed705d'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 53),
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a65b2cc5bb730f6ed705e'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 30, 0, 20, 49),
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed705f'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7061'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 13, 17, 24),
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7062'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 3, 53, 16),
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7064'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 29, 3, 52, 10),
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7067'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 11, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 28, 0, 33, 14),
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed706a'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 23, 0, 15, 12),
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b2cc5bb730f6ed706b'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 23, 0, 14, 47),
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7071'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 14, 0, 21, 26),
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7072'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 14, 0, 21, 7),
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7075'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 3, 52, 8),
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7076'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 1, 16, 38),
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7077'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 13, 1, 16, 37),
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7078'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 47, 32),
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7079'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 47, 16),
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed707a'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 4, 46, 53),
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b2cc5bb730f6ed707b'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 11, 12, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 12, 0, 33, 15),
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b2cc5bb730f6ed707d'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 11, 11, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 11, 15, 8),
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7081'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7082'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 56),
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7088'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 11, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 9, 4, 16, 46),
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed708b'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 11, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 11, 8, 5, 12, 8),
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7092'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 27, 4, 47, 31),
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed709a'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 10, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed709b'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 10, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 26, 4, 4, 53),
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed709f'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 10, 21, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 21, 1, 9, 54),
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70a3'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 10, 20, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 20, 0, 27, 12),
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70ad'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 10, 17, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 17, 4, 10, 38),
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70af'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 16, 23, 56, 43),
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70bb'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 10, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 4, 4, 41, 36),
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70c0'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 15, 1, 44),
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70c2'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#  'latitude': -37.236,
#  'longitude': 141.176,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70c3'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 3, 58, 28),
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70d1'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 10, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 3, 1, 22, 44),
#  'latitude': -37.227,
#  'longitude': 141.146,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70d2'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 23, 44, 31),
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70d3'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 4, 53, 10),
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70d8'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 10, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 2, 0, 39, 34),
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70d9'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 10, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 1, 15, 13, 56),
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70df'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 10, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 10, 1, 4, 10, 28),
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70e7'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 9, 27, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 27, 4, 35, 18),
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70ea'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 9, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 26, 3, 52, 14),
#  'latitude': -37.087,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70f7'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 13, 30, 9),
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70fd'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 19),
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70fe'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a65b2cc5bb730f6ed70ff'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7100'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 18),
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7103'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 17),
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7106'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 9, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 24, 4, 4, 4),
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7109'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 23, 50, 43),
#  'latitude': -37.559,
#  'longitude': 148.037,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed710a'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 23, 50, 40),
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('628a65b2cc5bb730f6ed710b'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 23, 50, 40),
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7114'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 18),
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7116'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 4, 59, 13),
#  'latitude': -37.347,
#  'longitude': 148.019,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a65b2cc5bb730f6ed711b'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 3, 21, 28),
#  'latitude': -36.995,
#  'longitude': 148.268,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a65b2cc5bb730f6ed711c'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 9, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 9, 23, 3, 21, 19),
#  'latitude': -37.554,
#  'longitude': 148.073,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712a'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 8, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 14, 4, 15, 40),
#  'latitude': -37.4421,
#  'longitude': 148.259,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712b'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 8, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 14, 4, 11),
#  'latitude': -38.0173,
#  'longitude': 144.0571,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712c'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 8, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 14, 4, 10, 20),
#  'latitude': -37.4754,
#  'longitude': 148.161,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712d'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 8, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 14, 4, 9, 30),
#  'latitude': -37.443,
#  'longitude': 147.3064,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712e'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 8, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 14, 4, 7, 50),
#  'latitude': -37.7836,
#  'longitude': 143.9688,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed712f'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 8, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 13, 5, 13, 30),
#  'latitude': -34.848,
#  'longitude': 141.5002,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7133'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 8, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 13, 5, 5),
#  'latitude': -34.8425,
#  'longitude': 141.4933,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7134'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 8, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 13, 5, 3, 10),
#  'latitude': -34.793,
#  'longitude': 141.5898,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7139'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 8, 5, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 5, 4, 20, 10),
#  'latitude': -37.8519,
#  'longitude': 147.2555,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed713b'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 8, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 8, 2, 3, 45),
#  'latitude': -37.491,
#  'longitude': 141.936,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7142'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 7, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 14, 4, 58, 10),
#  'latitude': -38.5194,
#  'longitude': 143.4522,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7143'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 7, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 14, 4, 50, 20),
#  'latitude': -38.5233,
#  'longitude': 143.433,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7146'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 7, 6, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 6, 4, 2),
#  'latitude': -37.8757,
#  'longitude': 143.428,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7147'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 7, 5, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 5, 23, 44),
#  'latitude': -38.4031,
#  'longitude': 147.0701,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7148'),
#  'confidence': 57,
#  'date': datetime.datetime(2021, 7, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 4, 4, 14),
#  'latitude': -37.8067,
#  'longitude': 141.7598,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed714b'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 10),
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a65b2cc5bb730f6ed714c'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 2, 4, 29, 10),
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a65b2cc5bb730f6ed714f'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 2, 4, 28, 42),
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7150'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 2, 4, 28, 42),
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7151'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 1, 13, 11, 41),
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7152'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 1, 13, 11, 41),
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7153'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 1, 3, 46, 8),
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7154'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 7, 1, 3, 46, 8),
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7163'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 6, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 18, 4, 14),
#  'latitude': -37.8387,
#  'longitude': 144.6301,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7164'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 6, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 16, 4, 34, 30),
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7165'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 6, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 16, 4, 26, 10),
#  'latitude': -36.7084,
#  'longitude': 142.7354,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7166'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 6, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 14, 4, 44, 10),
#  'latitude': -36.2669,
#  'longitude': 143.1906,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7168'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 6, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 14, 4, 40, 10),
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7169'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 6, 14, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 14, 4, 38, 30),
#  'latitude': -36.059,
#  'longitude': 143.7718,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed716a'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 6, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 13, 4, 2),
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed716b'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 6, 11, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 11, 4, 9, 40),
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed716c'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 6, 11, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 11, 4, 8),
#  'latitude': -37.6662,
#  'longitude': 142.9874,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7171'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 6, 7, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 7, 4, 36),
#  'latitude': -36.1858,
#  'longitude': 143.885,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7173'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 6, 7, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 7, 4, 35, 40),
#  'latitude': -36.2111,
#  'longitude': 141.505,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7174'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 6, 7, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 7, 4, 35, 30),
#  'latitude': -36.5794,
#  'longitude': 142.5959,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7177'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 6, 7, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'latitude': -36.2229,
#  'longitude': 143.4245,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7178'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 6, 7, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 7, 4, 32, 10),
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7181'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 6, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 30),
#  'latitude': -37.4661,
#  'longitude': 143.2419,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7185'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 6, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'latitude': -36.4422,
#  'longitude': 141.427,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7186'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 6, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 4, 4, 2, 10),
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed718c'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 6, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 40),
#  'latitude': -36.2032,
#  'longitude': 145.3025,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed718d'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 6, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7192'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 6, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 6, 2, 4, 14, 10),
#  'latitude': -36.6312,
#  'longitude': 142.5058,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7197'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 5, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 26, 4, 8, 10),
#  'latitude': -36.3334,
#  'longitude': 141.1515,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed719a'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 5, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 24, 4, 20, 20),
#  'latitude': -37.0585,
#  'longitude': 143.8589,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed719b'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 5, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 24, 0, 4, 20),
#  'latitude': -36.6859,
#  'longitude': 146.8907,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed719c'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 5, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 24, 0, 1, 50),
#  'latitude': -36.575,
#  'longitude': 146.6668,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a0'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 5, 23, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 23, 0, 54, 50),
#  'latitude': -37.9004,
#  'longitude': 141.0921,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a2'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 15, 30, 20),
#  'latitude': -36.6396,
#  'longitude': 146.8973,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a4'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 42, 20),
#  'latitude': -36.7889,
#  'longitude': 146.6495,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a5'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 38, 50),
#  'latitude': -36.4794,
#  'longitude': 144.5752,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a6'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 37, 20),
#  'latitude': -37.6198,
#  'longitude': 143.0357,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71a8'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 34, 50),
#  'latitude': -37.4857,
#  'longitude': 143.5322,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71ad'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 50),
#  'latitude': -36.7842,
#  'longitude': 146.9658,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71b6'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'latitude': -36.7871,
#  'longitude': 146.9604,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71b7'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'latitude': -37.5158,
#  'longitude': 142.8257,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71b9'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'latitude': -37.7287,
#  'longitude': 143.1682,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71ba'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 4, 32, 20),
#  'latitude': -37.7379,
#  'longitude': 143.1706,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71bf'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'latitude': -38.4322,
#  'longitude': 146.3208,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c0'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 22, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 22, 0, 13),
#  'latitude': -37.9077,
#  'longitude': 141.1101,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c3'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 3, 25),
#  'latitude': -36.1337,
#  'longitude': 146.1243,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c4'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 3, 21, 10),
#  'latitude': -36.8431,
#  'longitude': 147.5395,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c5'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 3, 21, 10),
#  'latitude': -36.8403,
#  'longitude': 147.5354,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c6'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 3, 21, 10),
#  'latitude': -36.1369,
#  'longitude': 146.116,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c7'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 0, 43, 10),
#  'latitude': -37.164,
#  'longitude': 148.915,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71c8'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 18, 0, 38, 10),
#  'latitude': -37.1521,
#  'longitude': 148.9446,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71cb'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 5, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 16, 3, 37, 40),
#  'latitude': -36.1875,
#  'longitude': 143.5158,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71cc'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 5, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 16, 3, 32, 50),
#  'latitude': -36.1887,
#  'longitude': 143.4722,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71cd'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 5, 16, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 16, 0, 48, 40),
#  'latitude': -37.2465,
#  'longitude': 144.3795,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71cf'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 35, 20),
#  'latitude': -36.4437,
#  'longitude': 143.5726,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71d0'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 34, 50),
#  'latitude': -36.3987,
#  'longitude': 142.6332,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71d4'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33, 20),
#  'latitude': -36.3065,
#  'longitude': 141.4495,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71d5'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 33, 20),
#  'latitude': -37.5074,
#  'longitude': 142.976,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71d8'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'latitude': -37.2622,
#  'longitude': 144.3704,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71d9'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'latitude': -36.3111,
#  'longitude': 143.7704,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71da'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'latitude': -36.7159,
#  'longitude': 141.4716,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71db'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 32, 50),
#  'latitude': -36.5963,
#  'longitude': 144.0066,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e3'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 40),
#  'latitude': -36.4216,
#  'longitude': 141.2799,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e4'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 40),
#  'latitude': -36.4317,
#  'longitude': 143.0967,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e5'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 30),
#  'latitude': -36.2538,
#  'longitude': 145.5929,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e6'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 30),
#  'latitude': -36.437,
#  'longitude': 144.1478,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e7'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 29, 10),
#  'latitude': -36.6217,
#  'longitude': 142.0944,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e8'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28, 40),
#  'latitude': -36.3652,
#  'longitude': 141.3508,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71e9'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28, 20),
#  'latitude': -36.8241,
#  'longitude': 145.1274,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71ea'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28, 10),
#  'latitude': -36.3296,
#  'longitude': 141.7522,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71eb'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 28, 10),
#  'latitude': -35.7542,
#  'longitude': 142.5039,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71f4'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 27, 10),
#  'latitude': -36.3019,
#  'longitude': 146.4343,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71f6'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 27, 10),
#  'latitude': -36.3542,
#  'longitude': 141.0935,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71f9'),
#  'confidence': 57,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 40),
#  'latitude': -35.6785,
#  'longitude': 143.5077,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed71fa'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 40),
#  'latitude': -36.6755,
#  'longitude': 141.5039,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7201'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.3971,
#  'longitude': 142.6444,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7203'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.4226,
#  'longitude': 143.0946,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7206'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.5646,
#  'longitude': 142.3068,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7209'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.7126,
#  'longitude': 141.6358,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed720a'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.4347,
#  'longitude': 143.5704,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed720d'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.7611,
#  'longitude': 141.6048,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed720e'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.5664,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7210'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.6483,
#  'longitude': 142.4878,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7214'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.86,
#  'longitude': 142.8137,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7215'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.3119,
#  'longitude': 146.4371,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7217'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.6463,
#  'longitude': 144.7594,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed721b'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -37.2794,
#  'longitude': 143.5903,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed721e'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -37.2811,
#  'longitude': 143.8819,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7225'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -36.0411,
#  'longitude': 141.7071,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7227'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -35.9903,
#  'longitude': 142.2708,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7231'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 5, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 15, 4, 26, 20),
#  'latitude': -37.7481,
#  'longitude': 143.4151,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7238'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 42, 20),
#  'latitude': -36.353,
#  'longitude': 144.5977,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7239'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 42),
#  'latitude': -36.4489,
#  'longitude': 144.1445,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed723a'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 42),
#  'latitude': -34.9917,
#  'longitude': 141.8885,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a65b2cc5bb730f6ed723b'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 42),
#  'latitude': -36.4032,
#  'longitude': 144.0604,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b2cc5bb730f6ed723e'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 20),
#  'latitude': -36.3883,
#  'longitude': 143.7526,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7241'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 40, 10),
#  'latitude': -36.5513,
#  'longitude': 144.1473,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed7244'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 39, 10),
#  'latitude': -36.6361,
#  'longitude': 144.5124,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b2cc5bb730f6ed724b'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 5, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 5, 13, 4, 38, 40),
#  'latitude': -37.1999,
#  'longitude': 143.6425,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b2cc5bb730f6ed724d'),
# ...
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7974'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#  'latitude': -36.2889,
#  'longitude': 141.7692,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7976'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#  'latitude': -36.6228,
#  'longitude': 142.428,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7978'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 4, 4, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 4, 4, 32, 40),
#  'latitude': -38.1177,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b3cc5bb730f6ed798e'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 53, 50),
#  'latitude': -37.8668,
#  'longitude': 143.0472,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed798f'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 53, 40),
#  'latitude': -37.7602,
#  'longitude': 143.382,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7991'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 53, 30),
#  'latitude': -37.7885,
#  'longitude': 142.9509,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed799d'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 52, 10),
#  'latitude': -37.8717,
#  'longitude': 143.2566,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79a2'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 51, 10),
#  'latitude': -37.8011,
#  'longitude': 144.7343,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79a8'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#  'latitude': -37.0241,
#  'longitude': 141.5163,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79a9'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#  'latitude': -37.2912,
#  'longitude': 143.543,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79aa'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#  'latitude': -37.313,
#  'longitude': 146.1561,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79ab'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 50),
#  'latitude': -38.0226,
#  'longitude': 143.6739,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79b0'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'latitude': -37.8089,
#  'longitude': 145.9555,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79b1'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'latitude': -37.9009,
#  'longitude': 143.6217,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79b3'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'latitude': -37.7836,
#  'longitude': 142.9437,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79b7'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'latitude': -37.0484,
#  'longitude': 141.6245,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79b8'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 3, 50, 40),
#  'latitude': -36.911,
#  'longitude': 142.1445,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79c0'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 1, 11),
#  'latitude': -34.2536,
#  'longitude': 141.6199,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79c4'),
#  'confidence': 57,
#  'date': datetime.datetime(2021, 4, 3, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 3, 1, 7),
#  'latitude': -34.2614,
#  'longitude': 141.6412,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79c5'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 4, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 2, 4, 53, 30),
#  'latitude': -36.3872,
#  'longitude': 145.3858,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79c8'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 4, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 2, 4, 45, 10),
#  'latitude': -36.494,
#  'longitude': 145.4522,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79c9'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 4, 2, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 2, 0, 24, 50),
#  'latitude': -37.324,
#  'longitude': 146.1647,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79ce'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 4, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#  'latitude': -36.2044,
#  'longitude': 145.7706,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79cf'),
#  'confidence': 57,
#  'date': datetime.datetime(2021, 4, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#  'latitude': -36.5245,
#  'longitude': 143.1556,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79d0'),
#  'confidence': 50,
#  'date': datetime.datetime(2021, 4, 1, 0, 0),
#  'datetime': datetime.datetime(2021, 4, 1, 4, 2, 40),
#  'latitude': -36.1002,
#  'longitude': 147.6494,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79da'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 50),
#  'latitude': -36.1649,
#  'longitude': 145.9352,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79db'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 40),
#  'latitude': -36.0436,
#  'longitude': 145.7964,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e1'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#  'latitude': -36.7134,
#  'longitude': 145.2151,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e2'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#  'latitude': -36.7028,
#  'longitude': 145.2519,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e3'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#  'latitude': -37.561,
#  'longitude': 143.242,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e4'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 4, 57, 10),
#  'latitude': -37.982,
#  'longitude': 143.6422,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e6'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 3, 31, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 31, 0, 36, 30),
#  'latitude': -34.2568,
#  'longitude': 141.64,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79e7'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 3, 29, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 29, 0, 48, 40),
#  'latitude': -34.2648,
#  'longitude': 141.6325,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a65b3cc5bb730f6ed79fa'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 3, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 28, 4, 29, 30),
#  'latitude': -37.6195,
#  'longitude': 143.4212,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a0d'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 3, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'latitude': -37.6376,
#  'longitude': 143.4255,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a17'),
#  'confidence': 69,
#  'date': datetime.datetime(2021, 3, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'latitude': -36.4422,
#  'longitude': 141.4172,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a1d'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 3, 28, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 28, 4, 26, 50),
#  'latitude': -34.342,
#  'longitude': 141.6548,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a21'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 3, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 26, 4, 41, 10),
#  'latitude': -38.1131,
#  'longitude': 143.7173,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a2b'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 3, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'latitude': -37.8469,
#  'longitude': 143.5343,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a2d'),
#  'confidence': 67,
#  'date': datetime.datetime(2021, 3, 26, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 26, 4, 39, 10),
#  'latitude': -37.1956,
#  'longitude': 141.0252,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a30'),
#  'confidence': 62,
#  'date': datetime.datetime(2021, 3, 25, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 25, 4, 3, 10),
#  'latitude': -37.8992,
#  'longitude': 143.4534,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a3b'),
#  'confidence': 57,
#  'date': datetime.datetime(2021, 3, 25, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 25, 3, 56, 40),
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a3c'),
#  'confidence': 65,
#  'date': datetime.datetime(2021, 3, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 24, 4, 58),
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a3d'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 3, 24, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 24, 4, 56, 10),
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a3f'),
#  'confidence': 58,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a41'),
#  'confidence': 63,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 39, 20),
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a42'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 36),
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a44'),
#  'confidence': 59,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 35),
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a45'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 50),
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a46'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a47'),
#  'confidence': 53,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 30),
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a48'),
#  'confidence': 61,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 33, 10),
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a4c'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 4, 32, 50),
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a52'),
#  'confidence': 60,
#  'date': datetime.datetime(2021, 3, 19, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 19, 0, 12, 50),
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a53'),
#  'confidence': 64,
#  'date': datetime.datetime(2021, 3, 18, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 18, 13, 16, 50),
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a5e'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a5f'),
#  'confidence': 66,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 50),
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a60'),
#  'confidence': 51,
#  'date': datetime.datetime(2021, 3, 15, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 15, 0, 42, 40),
#  'latitude': -37.002,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a6d'),
#  'confidence': 56,
#  'date': datetime.datetime(2021, 3, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 13, 23, 58, 50),
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a6e'),
#  'confidence': 52,
#  'date': datetime.datetime(2021, 3, 13, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 13, 12, 57),
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a79'),
#  'confidence': 55,
#  'date': datetime.datetime(2021, 3, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 10, 4, 43),
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a7a'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 3, 10, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 10, 4, 42, 30),
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a7d'),
#  'confidence': 54,
#  'date': datetime.datetime(2021, 3, 9, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 9, 3, 57),
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a65b3cc5bb730f6ed7a7f'),
#  'confidence': 68,
#  'date': datetime.datetime(2021, 3, 8, 0, 0),
#  'datetime': datetime.datetime(2021, 3, 8, 4, 51),
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}

# %% [markdown]
# h. Find the average surface temperature (°C) for each day. You are required to
# only display average surface temperature (°C) and the date in the output.

# %%
query_h_results = hotspot_historic.aggregate([
    {
        "$group":
        {
            "_id":"$date", 
            "avgSurfaceTemperature":{"$avg":"$surface_temperature_celcius"}
         }
    }])
for document in query_h_results:
    pprint(document)
# Out:
# {'_id': datetime.datetime(2021, 12, 27, 0, 0), 'avgSurfaceTemperature': 62.75}
# {'_id': datetime.datetime(2021, 7, 14, 0, 0), 'avgSurfaceTemperature': 41.5}
# {'_id': datetime.datetime(2021, 7, 5, 0, 0), 'avgSurfaceTemperature': 45.0}
# {'_id': datetime.datetime(2021, 4, 1, 0, 0),
#  'avgSurfaceTemperature': 46.714285714285715}
# {'_id': datetime.datetime(2021, 9, 21, 0, 0), 'avgSurfaceTemperature': 40.5}
# {'_id': datetime.datetime(2021, 8, 5, 0, 0), 'avgSurfaceTemperature': 40.0}
# {'_id': datetime.datetime(2021, 4, 23, 0, 0),
#  'avgSurfaceTemperature': 53.89473684210526}
# {'_id': datetime.datetime(2021, 3, 7, 0, 0), 'avgSurfaceTemperature': 64.0}
# {'_id': datetime.datetime(2021, 6, 18, 0, 0), 'avgSurfaceTemperature': 42.0}
# {'_id': datetime.datetime(2021, 6, 13, 0, 0), 'avgSurfaceTemperature': 41.0}
# {'_id': datetime.datetime(2021, 10, 28, 0, 0), 'avgSurfaceTemperature': 56.0}
# {'_id': datetime.datetime(2021, 11, 8, 0, 0), 'avgSurfaceTemperature': 45.5}
# {'_id': datetime.datetime(2021, 10, 21, 0, 0), 'avgSurfaceTemperature': 51.25}
# {'_id': datetime.datetime(2021, 12, 24, 0, 0), 'avgSurfaceTemperature': 32.0}
# {'_id': datetime.datetime(2021, 10, 3, 0, 0), 'avgSurfaceTemperature': 50.0}
# {'_id': datetime.datetime(2021, 5, 11, 0, 0),
#  'avgSurfaceTemperature': 59.36842105263158}
# {'_id': datetime.datetime(2021, 5, 3, 0, 0), 'avgSurfaceTemperature': 56.796875}
# {'_id': datetime.datetime(2021, 4, 11, 0, 0),
#  'avgSurfaceTemperature': 46.291666666666664}
# {'_id': datetime.datetime(2021, 11, 12, 0, 0), 'avgSurfaceTemperature': 53.0}
# {'_id': datetime.datetime(2021, 5, 8, 0, 0),
#  'avgSurfaceTemperature': 56.291666666666664}
# {'_id': datetime.datetime(2021, 4, 26, 0, 0), 'avgSurfaceTemperature': 34.0}
# {'_id': datetime.datetime(2021, 3, 14, 0, 0), 'avgSurfaceTemperature': 65.6}
# {'_id': datetime.datetime(2021, 9, 23, 0, 0),
#  'avgSurfaceTemperature': 52.73913043478261}
# {'_id': datetime.datetime(2021, 5, 14, 0, 0), 'avgSurfaceTemperature': 49.0}
# {'_id': datetime.datetime(2021, 5, 15, 0, 0),
#  'avgSurfaceTemperature': 53.950980392156865}
# {'_id': datetime.datetime(2021, 12, 12, 0, 0), 'avgSurfaceTemperature': 44.0}
# {'_id': datetime.datetime(2021, 4, 13, 0, 0),
#  'avgSurfaceTemperature': 58.57983193277311}
# {'_id': datetime.datetime(2021, 7, 4, 0, 0), 'avgSurfaceTemperature': 40.0}
# {'_id': datetime.datetime(2021, 10, 23, 0, 0), 'avgSurfaceTemperature': 38.0}
# {'_id': datetime.datetime(2021, 4, 4, 0, 0),
#  'avgSurfaceTemperature': 62.57303370786517}
# {'_id': datetime.datetime(2021, 4, 7, 0, 0),
#  'avgSurfaceTemperature': 50.69230769230769}
# {'_id': datetime.datetime(2021, 5, 4, 0, 0),
#  'avgSurfaceTemperature': 56.80740740740741}
# {'_id': datetime.datetime(2021, 5, 13, 0, 0),
#  'avgSurfaceTemperature': 58.611111111111114}
# {'_id': datetime.datetime(2021, 12, 15, 0, 0), 'avgSurfaceTemperature': 39.0}
# {'_id': datetime.datetime(2021, 4, 20, 0, 0),
#  'avgSurfaceTemperature': 56.58064516129032}
# {'_id': datetime.datetime(2021, 6, 3, 0, 0), 'avgSurfaceTemperature': 47.0}
# {'_id': datetime.datetime(2021, 4, 25, 0, 0),
#  'avgSurfaceTemperature': 48.666666666666664}
# {'_id': datetime.datetime(2021, 5, 23, 0, 0), 'avgSurfaceTemperature': 51.2}
# {'_id': datetime.datetime(2021, 12, 25, 0, 0), 'avgSurfaceTemperature': 54.0}
# {'_id': datetime.datetime(2021, 8, 10, 0, 0), 'avgSurfaceTemperature': 63.0}
# {'_id': datetime.datetime(2021, 4, 16, 0, 0),
#  'avgSurfaceTemperature': 48.72222222222222}
# {'_id': datetime.datetime(2021, 11, 29, 0, 0), 'avgSurfaceTemperature': 60.625}
# {'_id': datetime.datetime(2021, 3, 24, 0, 0), 'avgSurfaceTemperature': 49.0}
# {'_id': datetime.datetime(2021, 10, 7, 0, 0), 'avgSurfaceTemperature': 42.0}
# {'_id': datetime.datetime(2021, 10, 6, 0, 0), 'avgSurfaceTemperature': 44.0}
# {'_id': datetime.datetime(2021, 11, 9, 0, 0), 'avgSurfaceTemperature': 61.3}
# {'_id': datetime.datetime(2021, 3, 8, 0, 0), 'avgSurfaceTemperature': 51.5}
# {'_id': datetime.datetime(2021, 11, 22, 0, 0), 'avgSurfaceTemperature': 61.5}
# {'_id': datetime.datetime(2021, 3, 19, 0, 0),
#  'avgSurfaceTemperature': 65.57142857142857}
# {'_id': datetime.datetime(2021, 7, 31, 0, 0), 'avgSurfaceTemperature': 47.0}
# {'_id': datetime.datetime(2021, 4, 17, 0, 0),
#  'avgSurfaceTemperature': 50.921052631578945}
# {'_id': datetime.datetime(2021, 8, 14, 0, 0), 'avgSurfaceTemperature': 40.8}
# {'_id': datetime.datetime(2021, 4, 6, 0, 0),
#  'avgSurfaceTemperature': 61.71186440677966}
# {'_id': datetime.datetime(2021, 11, 11, 0, 0), 'avgSurfaceTemperature': 46.25}
# {'_id': datetime.datetime(2021, 4, 29, 0, 0), 'avgSurfaceTemperature': 63.0}
# {'_id': datetime.datetime(2021, 5, 17, 0, 0), 'avgSurfaceTemperature': 52.0}
# {'_id': datetime.datetime(2021, 6, 20, 0, 0),
#  'avgSurfaceTemperature': 71.16666666666667}
# {'_id': datetime.datetime(2021, 12, 9, 0, 0), 'avgSurfaceTemperature': 58.25}
# {'_id': datetime.datetime(2021, 10, 8, 0, 0), 'avgSurfaceTemperature': 41.0}
# {'_id': datetime.datetime(2021, 5, 24, 0, 0),
#  'avgSurfaceTemperature': 40.333333333333336}
# {'_id': datetime.datetime(2021, 4, 15, 0, 0),
#  'avgSurfaceTemperature': 59.57971014492754}
# {'_id': datetime.datetime(2021, 11, 30, 0, 0),
#  'avgSurfaceTemperature': 52.41935483870968}
# {'_id': datetime.datetime(2021, 3, 10, 0, 0), 'avgSurfaceTemperature': 69.375}
# {'_id': datetime.datetime(2021, 9, 24, 0, 0),
#  'avgSurfaceTemperature': 53.57142857142857}
# {'_id': datetime.datetime(2021, 10, 18, 0, 0),
#  'avgSurfaceTemperature': 52.166666666666664}
# {'_id': datetime.datetime(2021, 9, 27, 0, 0),
#  'avgSurfaceTemperature': 49.714285714285715}
# {'_id': datetime.datetime(2021, 6, 1, 0, 0), 'avgSurfaceTemperature': 54.0}
# {'_id': datetime.datetime(2021, 3, 25, 0, 0), 'avgSurfaceTemperature': 66.0}
# {'_id': datetime.datetime(2021, 8, 1, 0, 0), 'avgSurfaceTemperature': 58.0}
# {'_id': datetime.datetime(2021, 3, 13, 0, 0), 'avgSurfaceTemperature': 38.5}
# {'_id': datetime.datetime(2021, 6, 14, 0, 0), 'avgSurfaceTemperature': 53.25}
# {'_id': datetime.datetime(2021, 4, 12, 0, 0),
#  'avgSurfaceTemperature': 52.69565217391305}
# {'_id': datetime.datetime(2021, 3, 29, 0, 0), 'avgSurfaceTemperature': 51.0}
# {'_id': datetime.datetime(2021, 7, 2, 0, 0), 'avgSurfaceTemperature': 43.5}
# {'_id': datetime.datetime(2021, 6, 4, 0, 0),
#  'avgSurfaceTemperature': 52.22222222222222}
# {'_id': datetime.datetime(2021, 10, 10, 0, 0),
#  'avgSurfaceTemperature': 53.333333333333336}
# {'_id': datetime.datetime(2021, 12, 21, 0, 0), 'avgSurfaceTemperature': 46.0}
# {'_id': datetime.datetime(2021, 7, 6, 0, 0), 'avgSurfaceTemperature': 56.0}
# {'_id': datetime.datetime(2021, 10, 26, 0, 0), 'avgSurfaceTemperature': 44.6}
# {'_id': datetime.datetime(2021, 5, 22, 0, 0),
#  'avgSurfaceTemperature': 54.484848484848484}
# {'_id': datetime.datetime(2021, 5, 10, 0, 0),
#  'avgSurfaceTemperature': 52.86842105263158}
# {'_id': datetime.datetime(2021, 3, 18, 0, 0),
#  'avgSurfaceTemperature': 79.33333333333333}
# {'_id': datetime.datetime(2021, 10, 1, 0, 0), 'avgSurfaceTemperature': 48.25}
# {'_id': datetime.datetime(2021, 7, 1, 0, 0), 'avgSurfaceTemperature': 30.5}
# {'_id': datetime.datetime(2021, 9, 10, 0, 0), 'avgSurfaceTemperature': 56.5}
# {'_id': datetime.datetime(2021, 10, 16, 0, 0), 'avgSurfaceTemperature': 36.0}
# {'_id': datetime.datetime(2021, 12, 10, 0, 0), 'avgSurfaceTemperature': 46.0}
# {'_id': datetime.datetime(2021, 10, 27, 0, 0), 'avgSurfaceTemperature': 50.4}
# {'_id': datetime.datetime(2021, 5, 5, 0, 0),
#  'avgSurfaceTemperature': 51.70967741935484}
# {'_id': datetime.datetime(2021, 11, 14, 0, 0), 'avgSurfaceTemperature': 52.0}
# {'_id': datetime.datetime(2021, 10, 9, 0, 0), 'avgSurfaceTemperature': 44.0}
# {'_id': datetime.datetime(2021, 9, 22, 0, 0), 'avgSurfaceTemperature': 45.0}
# {'_id': datetime.datetime(2021, 6, 2, 0, 0),
#  'avgSurfaceTemperature': 47.72727272727273}
# {'_id': datetime.datetime(2021, 4, 2, 0, 0), 'avgSurfaceTemperature': 45.2}
# {'_id': datetime.datetime(2021, 3, 31, 0, 0),
#  'avgSurfaceTemperature': 48.72727272727273}
# {'_id': datetime.datetime(2021, 3, 15, 0, 0), 'avgSurfaceTemperature': 46.0}
# {'_id': datetime.datetime(2021, 11, 5, 0, 0), 'avgSurfaceTemperature': 58.5}
# {'_id': datetime.datetime(2021, 3, 9, 0, 0),
#  'avgSurfaceTemperature': 46.666666666666664}
# {'_id': datetime.datetime(2021, 3, 28, 0, 0),
#  'avgSurfaceTemperature': 60.925925925925924}
# {'_id': datetime.datetime(2021, 3, 26, 0, 0),
#  'avgSurfaceTemperature': 56.88235294117647}
# {'_id': datetime.datetime(2021, 12, 13, 0, 0), 'avgSurfaceTemperature': 60.0}
# {'_id': datetime.datetime(2021, 10, 4, 0, 0), 'avgSurfaceTemperature': 49.0}
# {'_id': datetime.datetime(2021, 12, 14, 0, 0), 'avgSurfaceTemperature': 70.0}
# {'_id': datetime.datetime(2021, 3, 17, 0, 0), 'avgSurfaceTemperature': 59.5}
# {'_id': datetime.datetime(2021, 4, 22, 0, 0), 'avgSurfaceTemperature': 54.5}
# {'_id': datetime.datetime(2021, 10, 20, 0, 0), 'avgSurfaceTemperature': 50.0}
# {'_id': datetime.datetime(2021, 6, 22, 0, 0), 'avgSurfaceTemperature': 46.0}
# {'_id': datetime.datetime(2021, 11, 13, 0, 0), 'avgSurfaceTemperature': 47.0}
# {'_id': datetime.datetime(2021, 4, 14, 0, 0),
#  'avgSurfaceTemperature': 61.94444444444444}
# {'_id': datetime.datetime(2021, 5, 2, 0, 0), 'avgSurfaceTemperature': 55.6}
# {'_id': datetime.datetime(2021, 8, 13, 0, 0), 'avgSurfaceTemperature': 49.0}
# {'_id': datetime.datetime(2021, 12, 8, 0, 0), 'avgSurfaceTemperature': 50.6}
# {'_id': datetime.datetime(2021, 11, 23, 0, 0), 'avgSurfaceTemperature': 58.8}
# {'_id': datetime.datetime(2021, 10, 15, 0, 0),
#  'avgSurfaceTemperature': 72.66666666666667}
# {'_id': datetime.datetime(2021, 9, 20, 0, 0), 'avgSurfaceTemperature': 63.6}
# {'_id': datetime.datetime(2021, 4, 5, 0, 0),
#  'avgSurfaceTemperature': 53.142857142857146}
# {'_id': datetime.datetime(2021, 6, 9, 0, 0), 'avgSurfaceTemperature': 49.0}
# {'_id': datetime.datetime(2021, 7, 29, 0, 0), 'avgSurfaceTemperature': 48.0}
# {'_id': datetime.datetime(2021, 5, 9, 0, 0),
#  'avgSurfaceTemperature': 42.46153846153846}
# {'_id': datetime.datetime(2021, 9, 29, 0, 0), 'avgSurfaceTemperature': 43.0}
# {'_id': datetime.datetime(2021, 4, 19, 0, 0), 'avgSurfaceTemperature': 54.16}
# {'_id': datetime.datetime(2021, 4, 24, 0, 0), 'avgSurfaceTemperature': 59.375}
# {'_id': datetime.datetime(2021, 3, 12, 0, 0), 'avgSurfaceTemperature': 88.2}
# {'_id': datetime.datetime(2021, 5, 18, 0, 0),
#  'avgSurfaceTemperature': 44.142857142857146}
# {'_id': datetime.datetime(2021, 4, 3, 0, 0),
#  'avgSurfaceTemperature': 58.44444444444444}
# {'_id': datetime.datetime(2021, 9, 26, 0, 0), 'avgSurfaceTemperature': 33.0}
# {'_id': datetime.datetime(2021, 6, 7, 0, 0),
#  'avgSurfaceTemperature': 51.857142857142854}
# {'_id': datetime.datetime(2021, 6, 11, 0, 0), 'avgSurfaceTemperature': 41.5}
# {'_id': datetime.datetime(2021, 5, 26, 0, 0), 'avgSurfaceTemperature': 49.5}
# {'_id': datetime.datetime(2021, 6, 30, 0, 0),
#  'avgSurfaceTemperature': 44.333333333333336}
# {'_id': datetime.datetime(2021, 8, 2, 0, 0), 'avgSurfaceTemperature': 63.5}
# {'_id': datetime.datetime(2021, 5, 1, 0, 0), 'avgSurfaceTemperature': 68.4}
# {'_id': datetime.datetime(2021, 5, 6, 0, 0),
#  'avgSurfaceTemperature': 57.529411764705884}
# {'_id': datetime.datetime(2021, 5, 16, 0, 0),
#  'avgSurfaceTemperature': 39.666666666666664}
# {'_id': datetime.datetime(2021, 5, 12, 0, 0), 'avgSurfaceTemperature': 51.5}
# {'_id': datetime.datetime(2021, 6, 16, 0, 0), 'avgSurfaceTemperature': 42.5}
# {'_id': datetime.datetime(2021, 4, 8, 0, 0), 'avgSurfaceTemperature': 60.75}
# {'_id': datetime.datetime(2021, 3, 6, 0, 0), 'avgSurfaceTemperature': 60.5}
# {'_id': datetime.datetime(2021, 5, 7, 0, 0),
#  'avgSurfaceTemperature': 50.333333333333336}
# {'_id': datetime.datetime(2021, 10, 17, 0, 0), 'avgSurfaceTemperature': 51.6}
# {'_id': datetime.datetime(2021, 12, 16, 0, 0), 'avgSurfaceTemperature': 57.8}
# {'_id': datetime.datetime(2021, 10, 2, 0, 0),
#  'avgSurfaceTemperature': 43.57142857142857}
# {'_id': datetime.datetime(2021, 11, 28, 0, 0), 'avgSurfaceTemperature': 42.0}
# {'_id': datetime.datetime(2021, 11, 21, 0, 0), 'avgSurfaceTemperature': 59.0}
# {'_id': datetime.datetime(2021, 4, 18, 0, 0),
#  'avgSurfaceTemperature': 53.36615384615384}

# %% [markdown]
# i. Find the top 10 records with the lowest GHI.

# %%
# sort the hotspot_historic data ascendingly based on GHI_w/m2 and get the top 10
query_i_results = climate_historic.find().sort("GHI_w/m2").limit(10)
for document in query_i_results:
    pprint(document)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f7f'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 8, 2, 0, 0),
#  'max_wind_speed': 5.1,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f5e'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 6, 30, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': {'amount': 0.0, 'flag': 'A'},
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f5f'),
#  'air_temperature_celcius': 5,
#  'date': datetime.datetime(2021, 7, 1, 0, 0),
#  'max_wind_speed': 14.0,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f69'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 11, 0, 0),
#  'max_wind_speed': 5.1,
#  'precipitation': {'amount': 0.01, 'flag': 'G'},
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f6d'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 15, 0, 0),
#  'max_wind_speed': 9.9,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f60'),
#  'air_temperature_celcius': 6,
#  'date': datetime.datetime(2021, 7, 2, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f7e'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 8, 1, 0, 0),
#  'max_wind_speed': 7.0,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f72'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 7, 20, 0, 0),
#  'max_wind_speed': 15.0,
#  'precipitation': {'amount': 0.12, 'flag': 'G'},
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f7d'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 7, 31, 0, 0),
#  'max_wind_speed': 8.0,
#  'precipitation': {'amount': 0.0, 'flag': 'I'},
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f90'),
#  'air_temperature_celcius': 7,
#  'date': datetime.datetime(2021, 8, 19, 0, 0),
#  'max_wind_speed': 9.9,
#  'precipitation': {'amount': 0.04, 'flag': 'G'},
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.

# %%
query_j_results = climate_historic.find({"precipitation.flag":{"$eq":'G'}, 
                                         "$and":[{"precipitation.amount":{"$gte":0.20}}, 
                                                 {"precipitation.amount":{"$lte":0.35}}]})

for result in query_j_results:
    pprint(result)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6eb6'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 1, 13, 0, 0),
#  'max_wind_speed': 18.1,
#  'precipitation': {'amount': 0.31, 'flag': 'G'},
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f01'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 3, 29, 0, 0),
#  'max_wind_speed': 21.0,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f17'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2021, 4, 20, 0, 0),
#  'max_wind_speed': 15.9,
#  'precipitation': {'amount': 0.31, 'flag': 'G'},
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f1d'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 4, 26, 0, 0),
#  'max_wind_speed': 20.0,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f3c'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2021, 5, 27, 0, 0),
#  'max_wind_speed': 19.0,
#  'precipitation': {'amount': 0.35, 'flag': 'G'},
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f3f'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 5, 30, 0, 0),
#  'max_wind_speed': 15.9,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f61'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 3, 0, 0),
#  'max_wind_speed': 18.1,
#  'precipitation': {'amount': 0.2, 'flag': 'G'},
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f79'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 7, 27, 0, 0),
#  'max_wind_speed': 21.0,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f83'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2021, 8, 6, 0, 0),
#  'max_wind_speed': 19.0,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6f97'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 8, 26, 0, 0),
#  'max_wind_speed': 19.0,
#  'precipitation': {'amount': 0.28, 'flag': 'G'},
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fa1'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2021, 9, 5, 0, 0),
#  'max_wind_speed': 18.1,
#  'precipitation': {'amount': 0.31, 'flag': 'G'},
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fa3'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2021, 9, 7, 0, 0),
#  'max_wind_speed': 14.0,
#  'precipitation': {'amount': 0.2, 'flag': 'G'},
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fab'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 9, 15, 0, 0),
#  'max_wind_speed': 15.0,
#  'precipitation': {'amount': 0.28, 'flag': 'G'},
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fbf'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2021, 10, 5, 0, 0),
#  'max_wind_speed': 18.1,
#  'precipitation': {'amount': 0.2, 'flag': 'G'},
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fd7'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2021, 10, 29, 0, 0),
#  'max_wind_speed': 27.0,
#  'precipitation': {'amount': 0.24, 'flag': 'G'},
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fd8'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2021, 10, 30, 0, 0),
#  'max_wind_speed': 14.0,
#  'precipitation': {'amount': 0.2, 'flag': 'G'},
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fe9'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2021, 11, 16, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': {'amount': 0.28, 'flag': 'G'},
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6fea'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2021, 11, 17, 0, 0),
#  'max_wind_speed': 12.0,
#  'precipitation': {'amount': 0.28, 'flag': 'G'},
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('628a65b1cc5bb730f6ed6ff7'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2021, 11, 30, 0, 0),
#  'max_wind_speed': 15.0,
#  'precipitation': {'amount': 0.2, 'flag': 'G'},
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# #### Reference
# - Converting string to datetime refer from: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
